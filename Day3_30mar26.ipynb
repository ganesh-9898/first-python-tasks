# %%
f1= ("250")
print(f1)
print(type(f1))
# Out:
# 250
# <class 'str'>

# %%
f1= ("99")
print(f1)
print(type(f1))
# Out:
# 99
# <class 'str'>

# %%
f1_float=float(f1)
print(f1_float)
print(type(f1_float))
# Out:
# 99.0
# <class 'float'>

# %%
f1_str=str(f1)
print(f1_str)
print(type(f1_str))
# Out:
# 99
# <class 'str'>

# %%
x= ("45.67")
print(type(x))
# Out:
# <class 'str'>

# %%
x_float=float(x)
print(type(x_float))
print(x_float)
# Out:
# <class 'float'>
# 45.67

# %%
x_int =int( x_float)
print(type(x_int))
print(x_int)
# Out:
# <class 'int'>
# 45

# %%
x_bool = int(False)
print(x_bool)
# Out:
# 0

# %%
f1 = (10,20,30)
f1_list = list(f1)
print(f1_list)
# Out:
# [10, 20, 30]

# %%
f5 = ["1","2","3","4","5"]
print(f5[0])
print(f5[4])
print(len(f5))
# Out:
# 1
# 5
# 5

# %%
s = "MachineLearning" 
print(s[:7])
print(s[-5:])
# Out:
# Machine
# rning

# %%
t = (1,2,3,4)
t[1]= 5     #tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 t = (1,2,3,4)
# ----> 2 t[1]= 5     #tuple is immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
h = "python"
h_list = [c for c in h]
print(h_list)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
nums = [5, 10, 15, 20]
nums.append(25)
nums.remove(10)
print(nums)
# Out:
# [5, 15, 20, 25]

# %%
x = "6789"
int_list = [int(c) for c in x]
print(int_list)
# Out:
# [6, 7, 8, 9]
