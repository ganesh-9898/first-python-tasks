# %%
x= 45
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
fruits = ["Apple","Banana","Kivi","coconut","walnut","Guava","Peach"]
fruits.append("Strawberry")
fruits.append("Orangw")
fruits.append("Grapes")
print(fruits)
# Out:
# ['Apple', 'Banana', 'Kivi', 'coconut', 'walnut', 'Guava', 'Peach', 'Strawberry', 'Orangw', 'Grapes']

# %%
fruits.remove("walnut")
print(fruits)
# Out:
# ['Apple', 'Banana', 'Kivi', 'coconut', 'Guava', 'Peach', 'Strawberry', 'Orangw', 'Grapes']

# %%
fruits.extend(["mango"])
print(fruits)
# Out:
# ['Apple', 'Banana', 'Kivi', 'coconut', 'Guava', 'Peach', 'Strawberry', 'Orangw', 'Grapes', 'mango']
